# %% [markdown]
# # 02 Corpus Processing
#
# Use this notebook to process raw corpus files into token and lemma-sentence index parquet files.
#
# ## Methodological warning
#
# This notebook is part of the ALTE Common Corpus SIG / European CEFR Vocabulary Atlas pilot workflow. Outputs produced by LLM-assisted steps are provisional Tier 4 candidate material only. They are not validated CEFR data and require expert review.

# %%
from pathlib import Path
import os
import pandas as pd

REPO_ROOT = Path('/content/ALTE-Common-Corpus-SIG')
DRIVE_ROOT = Path('/content/drive/MyDrive/ALTE-Common-Corpus-SIG')

print('REPO_ROOT:', REPO_ROOT)
print('DRIVE_ROOT:', DRIVE_ROOT)

# %% [markdown]
# ## Define languages and paths
#
# Set language codes and expected input/output locations.

# %%
LANGUAGES = ['en', 'fr', 'es', 'de', 'cs']

for lang in LANGUAGES:
    raw_dir = DRIVE_ROOT / 'data' / 'raw' / lang / 'corpus_original'
    token_dir = DRIVE_ROOT / 'data' / 'interim' / lang / 'tokens'
    index_dir = DRIVE_ROOT / 'data' / 'interim' / lang / 'lemma_sentence_index'

    print(lang)
    print(' raw:', raw_dir)
    print(' tokens:', token_dir)
    print(' index:', index_dir)

# %% [markdown]
# ## Corpus processing placeholder
#
# This is where the language-specific tokenisation, sentence splitting, POS tagging and lemmatisation scripts should be called.

# %%
# Example future command:
# !python scripts/process_corpus.py --lang en

print('Corpus processing scripts will be called from here once scripts/process_corpus.py is finalised.')
