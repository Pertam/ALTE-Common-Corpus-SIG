# %% [markdown]
# # 06 QA and Review Workbook
#
# Use this notebook to run quality checks and export reviewer-facing Excel workbooks.
#
# ## Methodological warning
#
# This notebook is part of the ALTE Common Corpus SIG / European CEFR Vocabulary Atlas pilot workflow. Outputs produced by LLM-assisted steps are provisional Tier 4 candidate material only. They are not validated CEFR data and require expert review.

# %%
from pathlib import Path
import os
import pandas as pd

REPO_ROOT = Path('/content/ALTE-Common-Corpus-SIG')
DRIVE_ROOT = Path('/content/drive/MyDrive/ALTE-Common-Corpus-SIG')

print('REPO_ROOT:', REPO_ROOT)
print('DRIVE_ROOT:', DRIVE_ROOT)

# %% [markdown]
# ## Define QA output paths
#
# Set the expected output folders for QA reports and review workbooks.

# %%
LANG = 'en'

qa_dir = DRIVE_ROOT / 'data' / 'outputs' / LANG / 'qa'
review_dir = DRIVE_ROOT / 'data' / 'outputs' / LANG / 'review_workbooks'

qa_dir.mkdir(parents=True, exist_ok=True)
review_dir.mkdir(parents=True, exist_ok=True)

print('QA directory:', qa_dir)
print('Review workbook directory:', review_dir)

# %% [markdown]
# ## Run QA checks
#
# Check controlled values, missing fields, invalid labels, inconsistent pass decisions and review status issues.

# %%
# Example future command:
# !python scripts/run_qa_checks.py --lang en

print('QA script will be called from here once scripts/run_qa_checks.py is finalised.')

# %% [markdown]
# ## Export review workbook
#
# Create an Excel workbook for expert review.

# %%
# Example future command:
# !python scripts/export_review_workbook.py --lang en

print('Review workbook export script will be called from here once scripts/export_review_workbook.py is finalised.')
