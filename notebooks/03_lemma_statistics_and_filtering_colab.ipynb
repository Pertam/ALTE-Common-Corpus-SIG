# %% [markdown]
# # 03 Lemma Statistics and Filtering
#
# Use this notebook to calculate lemma statistics and filter content-word lemmas by ARF per million.
#
# ## Methodological warning
#
# This notebook is part of the ALTE Common Corpus SIG / European CEFR Vocabulary Atlas pilot workflow. Outputs produced by LLM-assisted steps are provisional Tier 4 candidate material only. They are not validated CEFR data and require expert review.

# %%
from pathlib import Path
import os
import pandas as pd

REPO_ROOT = Path('/content/ALTE-Common-Corpus-SIG')
DRIVE_ROOT = Path('/content/drive/MyDrive/ALTE-Common-Corpus-SIG')

print('REPO_ROOT:', REPO_ROOT)
print('DRIVE_ROOT:', DRIVE_ROOT)

# %% [markdown]
# ## Define filtering settings
#
# The current pilot uses content POS only and ARF per million ≥ 50.

# %%
CONTENT_POS = {'NOUN', 'VERB', 'ADJ', 'ADV'}
ARF_THRESHOLD = 50

print('CONTENT_POS:', CONTENT_POS)
print('ARF_THRESHOLD:', ARF_THRESHOLD)

# %% [markdown]
# ## Run lemma statistics script
#
# Call the lemma statistics script once available.

# %%
# Example future command:
# !python scripts/calculate_lemma_statistics.py --lang en --arf-threshold 50

print('Lemma statistics script will be called from here once scripts/calculate_lemma_statistics.py is finalised.')
