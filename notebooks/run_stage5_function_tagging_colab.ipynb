# %% [markdown]
# <a href="https://colab.research.google.com/github/Pertam/ALTE-Common-Corpus-SIG/blob/main/notebooks/run_stage5_function_tagging_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Pertam/ALTE-Common-Corpus-SIG.git
# %cd ALTE-Common-Corpus-SIG
# Out:
# Cloning into 'ALTE-Common-Corpus-SIG'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 33 (delta 4), reused 18 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 9.88 KiB | 9.88 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/ALTE-Common-Corpus-SIG

# %%
# !ls
# !git status
# Out:
# config	     notebooks	requirements.txt			 scripts
# docs	     prompts	run_stage5_function_tagging_colab.ipynb  taxonomy
# methodology  README.md	sample_data
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
from pathlib import Path

REPO_DIR = Path("/content/ALTE-Common-Corpus-SIG")

if REPO_DIR.exists():
    print("Repo already exists.")
else:
    # !git clone https://github.com/Pertam/ALTE-Common-Corpus-SIG.git /content/ALTE-Common-Corpus-SIG

# %cd /content/ALTE-Common-Corpus-SIG
# !git status
# Out:
# Repo already exists.
# /content/ALTE-Common-Corpus-SIG
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/ALTE-Common-Corpus-SIG
# !git pull
# Out:
# /content/ALTE-Common-Corpus-SIG
# Already up to date.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

REPO_ROOT = Path("/content/ALTE-Common-Corpus-SIG")
DRIVE_ROOT = Path("/content/drive/MyDrive/ALTE-Common-Corpus-SIG")

print("Repo exists:", REPO_ROOT.exists())
print("Drive exists:", DRIVE_ROOT.exists())
# Out:
# Repo exists: True
# Drive exists: True

# %%
from pathlib import Path
from google.colab import drive

REPO_DIR = Path("/content/ALTE-Common-Corpus-SIG")

if REPO_DIR.exists():
    print("Repo already exists.")
else:
    # !git clone https://github.com/Pertam/ALTE-Common-Corpus-SIG.git /content/ALTE-Common-Corpus-SIG

# %cd /content/ALTE-Common-Corpus-SIG
# !git pull
# !git status

drive.mount("/content/drive")

REPO_ROOT = Path("/content/ALTE-Common-Corpus-SIG")
DRIVE_ROOT = Path("/content/drive/MyDrive/ALTE-Common-Corpus-SIG")

print("REPO_ROOT:", REPO_ROOT)
print("DRIVE_ROOT:", DRIVE_ROOT)
# Out:
# Repo already exists.
# /content/ALTE-Common-Corpus-SIG
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# REPO_ROOT: /content/ALTE-Common-Corpus-SIG
# DRIVE_ROOT: /content/drive/MyDrive/ALTE-Common-Corpus-SIG
