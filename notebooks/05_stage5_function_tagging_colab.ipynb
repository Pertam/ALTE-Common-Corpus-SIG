# %% [markdown]
# # 05 Stage 5 Function Tagging
#
# Use this notebook to run Pass 1, Pass 2 and Pass 3 sentence-level CEFR function tagging.
#
# ## Methodological warning
#
# This notebook is part of the ALTE Common Corpus SIG / European CEFR Vocabulary Atlas pilot workflow. Outputs produced by LLM-assisted steps are provisional Tier 4 candidate material only. They are not validated CEFR data and require expert review.

# %%
from pathlib import Path
import os
import pandas as pd

REPO_ROOT = Path('/content/ALTE-Common-Corpus-SIG')
DRIVE_ROOT = Path('/content/drive/MyDrive/ALTE-Common-Corpus-SIG')

print('REPO_ROOT:', REPO_ROOT)
print('DRIVE_ROOT:', DRIVE_ROOT)

# %% [markdown]
# ## Check input files
#
# Confirm that the English sample and taxonomy are visible.

# %%
sample_path = DRIVE_ROOT / 'data' / 'interim' / 'en' / 'samples' / 'stage5_en_random_15_lemmas_all_sentences.csv'
taxonomy_path = REPO_ROOT / 'taxonomy' / 'cefr_function_taxonomy.csv'

print('Sample exists:', sample_path.exists(), sample_path)
print('Taxonomy exists:', taxonomy_path.exists(), taxonomy_path)

if sample_path.exists():
    sample = pd.read_csv(sample_path)
    print('Sample rows:', len(sample))
    display(sample.head())

# %% [markdown]
# ## Set OpenAI API key
#
# Set the API key for this Colab session only. Do not save it in GitHub.

# %%
from getpass import getpass
import os

# Uncomment when ready to run API calls.
# os.environ['OPENAI_API_KEY'] = getpass('Paste OpenAI API key: ')
# print('OpenAI API key set for this session.')

# %% [markdown]
# ## Run Pass 1
#
# Run first-pass sentence-level function tagging.

# %%
# Example future command:
# !python scripts/run_pass1.py --lang en

print('Pass 1 script will be called from here once scripts/run_pass1.py is finalised.')

# %% [markdown]
# ## Run Pass 2
#
# Run blind validation against first-pass labels.

# %%
# Example future command:
# !python scripts/run_pass2.py --lang en

print('Pass 2 script will be called from here once scripts/run_pass2.py is finalised.')

# %% [markdown]
# ## Run Pass 3
#
# Run lemma-level aggregation and functional environment profiling.

# %%
# Example future command:
# !python scripts/run_pass3.py --lang en

print('Pass 3 script will be called from here once scripts/run_pass3.py is finalised.')
